# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#  1. read csv file and print 1st 5 rows
df = pd.read_csv('diamonds.csv')
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
# 2. print first 6
df.head(6)
df.rename(columns={'cut': 'Quality'})
# Out:
#        Unnamed: 0  carat    Quality color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
# 3. select a series from dataframe and print contents of it
df['color']
# Out:
# 0        E
# 1        E
# 2        E
# 3        I
# 4        J
#         ..
# 53935    D
# 53936    D
# 53937    D
# 53938    H
# 53939    D
# Name: color, Length: 53940, dtype: object

# %%
# 4. create a new 'Quality-color' Series
df['Quality-color'] = df.cut + ', ' + df.color

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z Quality-color
# ...

# %%
# 5. number of rows and columns
df.shape
# Out:
# (53940, 12)

# %%
# 5. type of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     53940 non-null  int64
#  1   carat          53940 non-null  float64
#  2   cut            53940 non-null  object
#  3   color          53940 non-null  object
#  4   clarity        53940 non-null  object
#  5   depth          53940 non-null  float64
#  6   table          53940 non-null  float64
#  7   price          53940 non-null  int64
#  8   x              53940 non-null  float64
#  9   y              53940 non-null  float64
#  10  z              53940 non-null  float64
#  11  Quality-color  53940 non-null  object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 4.9+ MB

# %%
# 6. summarize only 'object' columns of the diamonds
df.describe(include=['object'])
# Out:
#           cut  color clarity Quality-color
# count   53940  53940   53940         53940
# unique      5      7       8            35
# top     Ideal      G     SI1      Ideal, G
# freq    21551  11292   13065          4884

# %%
# 7. Rename two columns
df.rename(columns={'x':'X', 'y': 'Y'})
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z Quality-color
# ...

# %%
# 8. rename all columns
df.rename(columns={'carat': 'Carat', 'Quality': 'Qlty', 'color': 'Color', 'clarity': 'Clarity', 'depth': 'Depth', 'table': 'Table', 'price': 'Price', 'X': 'x', 'Y':'y', 'z': 'z', 'Quality-color': 'Qlty-color'})
# Out:
#        Unnamed: 0  Carat        cut Color Clarity  Depth  Table  Price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z    Qlty-color
# ...

# %%
# 9. remove the 2nd column
df.drop(df.columns[1], axis=1)
# Out:
#        Unnamed: 0        cut color clarity  depth  table  price     x     y  \
# 0               1      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1               2    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2               3       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3               4    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4               5       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...           ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935       53936      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936       53937       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937       53938  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938       53939    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939       53940      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z Quality-color
# 0      2.43      Ideal, E
# ...

# %%
# 10. delete multiple columns
df.drop(['cut', 'color'], axis=1)
# Out:
#        Unnamed: 0  carat clarity  depth  table  price     x     y     z  \
# 0               1   0.23     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1               2   0.21     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2               3   0.23     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3               4   0.29     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4               5   0.31     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...           ...    ...     ...    ...    ...    ...   ...   ...   ...
# 53935       53936   0.72     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936       53937   0.72     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937       53938   0.70     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938       53939   0.86     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939       53940   0.75     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-color
# 0          Ideal, E
# 1        Premium, E
# 2           Good, E
# ...

# %%
# 11. multiple rows deletion
df.drop([2,3],axis=0)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z Quality-color
# ...

# %%
# 12. sort the cut series in ascending order
df.sort_values(by='cut')
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 3850         3851   1.01       Fair     F     SI2   64.8   55.0   3477  6.37
# 51464       51465   1.20       Fair     G      I1   66.6   57.0   2376  6.57
# 51466       51467   0.90       Fair     G     SI2   65.4   57.0   2376  6.01
# 10237       10238   1.26       Fair     D     SI2   64.5   59.0   4746  6.75
# 10760       10761   1.01       Fair     E     SI1   69.5   55.0   4853  6.00
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 7402         7403   0.33  Very Good     G     VS2   62.8   54.0    579  4.40
# 43101       43102   0.57  Very Good     E     SI2   58.8   57.3   1384  5.42
# 16893       16894   1.00  Very Good     G     VS2   62.2   58.0   6743  6.35
# 16898       16899   1.00  Very Good     D     VS2   59.6   60.0   6745  6.52
# 21164       21165   1.00  Very Good     E    VVS2   61.7   55.0   9324  6.38
#
#           y     z Quality-color
# ...

# %%
# 13. to sort price series in descending order
df.sort_values(by='price',ascending=False)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27747       27748   1.51      Ideal     G      IF   61.7   55.0  18806  7.37
# 27746       27747   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20
# 27745       27746   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
#
#           y     z Quality-color
# ...

# %%
# 14. sort the entire diamonds dataframe by the 'carat' series in ascending and descending order
df.sort_values(by='carat') # by ascending
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price      x  \
# 31593       31594   0.20  Premium     E     VS2   61.1   59.0    367   3.81
# 31597       31598   0.20    Ideal     D     VS2   61.5   57.0    367   3.81
# 31596       31597   0.20  Premium     F     VS2   62.6   59.0    367   3.73
# 31595       31596   0.20    Ideal     E     VS2   59.7   55.0    367   3.86
# 31594       31595   0.20  Premium     E     VS2   59.7   62.0    367   3.84
# ...           ...    ...      ...   ...     ...    ...    ...    ...    ...
# 25999       26000   4.01  Premium     J      I1   62.5   62.0  15223  10.02
# 25998       25999   4.01  Premium     I      I1   61.0   61.0  15223  10.14
# 27130       27131   4.13     Fair     H      I1   64.8   61.0  17329  10.00
# 27630       27631   4.50     Fair     J      I1   65.8   58.0  18531  10.23
# 27415       27416   5.01     Fair     J      I1   65.5   59.0  18018  10.74
#
#            y     z Quality-color
# ...

# %%
df.sort_values(by='carat',ascending=False)
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price      x  \
# 27415       27416   5.01     Fair     J      I1   65.5   59.0  18018  10.74
# 27630       27631   4.50     Fair     J      I1   65.8   58.0  18531  10.23
# 27130       27131   4.13     Fair     H      I1   64.8   61.0  17329  10.00
# 25999       26000   4.01  Premium     J      I1   62.5   62.0  15223  10.02
# 25998       25999   4.01  Premium     I      I1   61.0   61.0  15223  10.14
# ...           ...    ...      ...   ...     ...    ...    ...    ...    ...
# 31592       31593   0.20  Premium     E     VS2   59.0   60.0    367   3.81
# 31591       31592   0.20  Premium     E     VS2   59.8   62.0    367   3.79
# 31601       31602   0.20  Premium     D     VS2   61.7   60.0    367   3.77
# 14             15   0.20  Premium     E     SI2   60.2   62.0    345   3.79
# 31596       31597   0.20  Premium     F     VS2   62.6   59.0    367   3.73
#
#            y     z Quality-color
# ...

# %%
# 15.filter the dataframe to rows to only show carat weight at least 0.3
df[df['carat']>0.3]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 13             14   0.31      Ideal     J     SI2   62.2   54.0    344  4.35
# 15             16   0.32    Premium     E      I1   60.9   58.0    345  4.38
# 23             24   0.31  Very Good     J     SI1   59.4   62.0    353  4.39
# 24             25   0.31  Very Good     J     SI1   58.1   62.0    353  4.44
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z Quality-color
# ...

# %%
# 16. convert python list to pandas series
lst = [1,2,3,4,5]
s1 = pd.Series(lst)
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# 17. find details of diamond where len>5,width>5 and depth>5
df[(df.x>5) & (df.y>5) & (df.z>5)]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 11778       11779   1.83       Fair     J      I1   70.0   58.0   5083  7.34
# 13002       13003   2.14       Fair     J      I1   69.4   57.0   5405  7.74
# 13118       13119   2.15       Fair     J      I1   65.5   57.0   5430  8.01
# 13562       13563   1.96       Fair     F      I1   66.6   60.0   5554  7.59
# 13757       13758   2.22       Fair     J      I1   66.7   56.0   5607  8.04
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
# 48410       48411   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12
# 49189       49190   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15
# 49905       49906   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01
#
#            y      z Quality-color
# ...

# %%
# 18. display diamonds that are either premium or ideal
df[(df.cut=='Premium')| (df.cut=='Ideal')]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 0               1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21  Premium     E     SI1   59.8   61.0    326  3.89
# 3               4   0.29  Premium     I     VS2   62.4   58.0    334  4.20
# 11             12   0.23    Ideal     J     VS1   62.8   56.0    340  3.93
# 12             13   0.22  Premium     F     SI1   60.4   61.0    342  3.88
# ...           ...    ...      ...   ...     ...    ...    ...    ...   ...
# 53931       53932   0.71  Premium     F     SI1   59.8   62.0   2756  5.74
# 53934       53935   0.72  Premium     D     SI1   62.7   59.0   2757  5.69
# 53935       53936   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75
# 53938       53939   0.86  Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z Quality-color
# 0      3.98  2.43      Ideal, E
# ...

# %%
# 19. to find diamonds that are with a fair good or good or premium
df.loc[(df.cut == 'Fair')| (df.cut == 'Good')| (df.cut=='Premium')]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 1               2   0.21  Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23     Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29  Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31     Good     J     SI2   63.3   58.0    335  4.34
# 8               9   0.22     Fair     E     VS2   65.1   61.0    337  3.87
# ...           ...    ...      ...   ...     ...    ...    ...    ...   ...
# 53930       53931   0.71  Premium     E     SI1   60.5   55.0   2756  5.79
# 53931       53932   0.71  Premium     F     SI1   59.8   62.0   2756  5.74
# 53934       53935   0.72  Premium     D     SI1   62.7   59.0   2757  5.69
# 53936       53937   0.72     Good     D     SI1   63.1   55.0   2757  5.69
# 53938       53939   0.86  Premium     H     SI2   61.0   58.0   2757  6.15
#
#           y     z Quality-color
# 1      3.84  2.31    Premium, E
# ...

# %%
# 20. All column labels of diamonds dataframe
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z', 'Quality-color'],
#       dtype='object')

# %%
# 21. read subset of 3 rows
subs = df.iloc[:3]
subs
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
#
#       z Quality-color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E

# %%
# 22. iterate through diamonds dataframe
randIndexes = np.random.randint(0, 5398, 50)
for i in randIndexes:
    print(df.loc[i], '\n')
# Out:
# Unnamed: 0           3160
# carat                0.72
# cut                 Ideal
# color                   H
# clarity              VVS2
# depth                61.6
# table                56.0
# price                3334
# x                    5.75
# y                    5.77
# z                    3.55
# Quality-color    Ideal, H
# Name: 3159, dtype: object
#
# Unnamed: 0           5340
# carat                 1.0
# cut                 Ideal
# color                   I
# clarity               SI2
# depth                60.9
# table                57.0
# price                3811
# x                    6.43
# y                    6.47
# z                    3.93
# Quality-color    Ideal, I
# Name: 5339, dtype: object
#
# Unnamed: 0           3228
# carat                0.72
# cut                 Ideal
# color                   G
# clarity              VVS2
# depth                62.0
# table                55.0
# price                3352
# x                    5.72
# ...

# %%
# 23. drop all non-numeric columns
df_numeric = df.select_dtypes(include=['number'])
df_numeric
# Out:
#        Unnamed: 0  carat  depth  table  price     x     y     z
# 0               1   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1               2   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2               3   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3               4   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4               5   0.31   63.3   58.0    335  4.34  4.35  2.75
# ...           ...    ...    ...    ...    ...   ...   ...   ...
# 53935       53936   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936       53937   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937       53938   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938       53939   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939       53940   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 8 columns]

# %%
# 24.include only numeric columns
df_numeric
# Out:
#        Unnamed: 0  carat  depth  table  price     x     y     z
# 0               1   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1               2   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2               3   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3               4   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4               5   0.31   63.3   58.0    335  4.34  4.35  2.75
# ...           ...    ...    ...    ...    ...   ...   ...   ...
# 53935       53936   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936       53937   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937       53938   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938       53939   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939       53940   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 8 columns]

# %%
# 25. pass a list of data types to only describe certain types of diamonds df

# %%
# 26. Calculate mean of each numeric column in dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     53940 non-null  int64
#  1   carat          53940 non-null  float64
#  2   cut            53940 non-null  object
#  3   color          53940 non-null  object
#  4   clarity        53940 non-null  object
#  5   depth          53940 non-null  float64
#  6   table          53940 non-null  float64
#  7   price          53940 non-null  int64
#  8   x              53940 non-null  float64
#  9   y              53940 non-null  float64
#  10  z              53940 non-null  float64
#  11  Quality-color  53940 non-null  object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 4.9+ MB

# %%
df['carat'].mean
# Out:
# <bound method Series.mean of 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64>

# %%
df['depth'].mean
# Out:
# <bound method Series.mean of 0        61.5
# 1        59.8
# 2        56.9
# 3        62.4
# 4        63.3
#          ...
# 53935    60.8
# 53936    63.1
# 53937    62.8
# 53938    61.0
# 53939    62.2
# Name: depth, Length: 53940, dtype: float64>

# %%
df['table'].mean
# Out:
# <bound method Series.mean of 0        55.0
# 1        61.0
# 2        65.0
# 3        58.0
# 4        58.0
#          ...
# 53935    57.0
# 53936    55.0
# 53937    60.0
# 53938    58.0
# 53939    55.0
# Name: table, Length: 53940, dtype: float64>

# %%
df['price'].mean
# Out:
# <bound method Series.mean of 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64>

# %%
df['x'].mean
# Out:
# <bound method Series.mean of 0        3.95
# 1        3.89
# 2        4.05
# 3        4.20
# 4        4.34
#          ...
# 53935    5.75
# 53936    5.69
# 53937    5.66
# 53938    6.15
# 53939    5.83
# Name: x, Length: 53940, dtype: float64>

# %%
df['y'].mean
# Out:
# <bound method Series.mean of 0        3.98
# 1        3.84
# 2        4.07
# 3        4.23
# 4        4.35
#          ...
# 53935    5.76
# 53936    5.75
# 53937    5.68
# 53938    6.12
# 53939    5.87
# Name: y, Length: 53940, dtype: float64>

# %%
df['z'].mean
# Out:
# <bound method Series.mean of 0        2.43
# 1        2.31
# 2        2.31
# 3        2.63
# 4        2.75
#          ...
# 53935    3.50
# 53936    3.61
# 53937    3.56
# 53938    3.74
# 53939    3.64
# Name: z, Length: 53940, dtype: float64>

# %%
# 27. calculate mean of each row in dataframe
rows = [0, len(df)-1]

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality-color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %%
# df['mean'] = df.mean(axis=1)

# %%
# 28. mean price of each cut of diamond frame
df['cut'].mean
# Out:
# <bound method Series.mean of 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: object>

# %%
# 29. To calculate count,minimum,maximum price for each cut of diamonds dataframe
# count
df.groupby('cut').count()
# Out:
#            Unnamed: 0  carat  color  clarity  depth  table  price      x  \
# cut
# Fair             1610   1610   1610     1610   1610   1610   1610   1610
# Good             4906   4906   4906     4906   4906   4906   4906   4906
# Ideal           21551  21551  21551    21551  21551  21551  21551  21551
# Premium         13791  13791  13791    13791  13791  13791  13791  13791
# Very Good       12082  12082  12082    12082  12082  12082  12082  12082
#
#                y      z  Quality-color
# cut
# Fair        1610   1610           1610
# Good        4906   4906           4906
# Ideal      21551  21551          21551
# Premium    13791  13791          13791
# Very Good  12082  12082          12082

# %%
# minimum
df.groupby('cut').min()
# Out:
#            Unnamed: 0  carat color clarity  depth  table  price    x    y  \
# cut
# Fair                9   0.22     D      I1   43.0   49.0    337  0.0  0.0
# Good                3   0.23     D      I1   54.3   51.0    327  0.0  0.0
# Ideal               1   0.20     D      I1   43.0   43.0    326  0.0  0.0
# Premium             2   0.20     D      I1   58.0   51.0    326  0.0  0.0
# Very Good           6   0.20     D      I1   56.8   44.0    336  0.0  0.0
#
#              z Quality-color
# cut
# Fair       0.0       Fair, D
# Good       0.0       Good, D
# Ideal      0.0      Ideal, D
# Premium    0.0    Premium, D
# Very Good  0.0  Very Good, D

# %%
# maximum
df.groupby('cut').max
# Out:
# <bound method GroupBy.max of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001F6AD8E3B00>>

# %%
mean_prices = df.groupby('cut')['price'].mean().reset_index()

# %%
# 30. pandas program to create side-by-side bar plot of the diamonds dataframe
# Create a side-by-side bar plot
plt.bar(mean_prices['cut'], mean_prices['price'], color='hotpink')
plt.xlabel('Cut')
plt.ylabel('Mean Price')
plt.title('Mean Price of Diamonds by Cut')
plt.xticks(rotation=45)
plt.show()

# %%
# 31. To count how many times each value in cut series of diamonds dataframe occurs
df.cut.value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
# 32. pandas program to display percentages of each value of cut series occurs in diamonds dataframe
df.cut.value_counts(normalize=True)
# Out:
# cut
# Ideal        0.399537
# Premium      0.255673
# Very Good    0.223990
# Good         0.090953
# Fair         0.029848
# Name: proportion, dtype: float64

# %%
# 33. to display unique values in cut series of diamonds dataframe
df.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
# 34. to count number of unique values in cut series
df.cut.nunique()
# Out:
# 5

# %%
# 35. to compute cross-tabulation of two series in the diamonds dataframe
pd.crosstab(df['cut'],df['price'])
# Out:
# price      326    327    334    335    336    337    338    339    340    \
# cut
# Fair           0      0      0      0      0      1      0      0      0
# Good           0      1      0      1      0      0      0      1      0
# Ideal          1      0      0      0      0      0      0      0      1
# Premium        1      0      1      0      0      0      0      0      0
# Very Good      0      0      0      0      2      1      1      0      0
#
# price      342    ...  18787  18788  18791  18795  18797  18803  18804  18806  \
# cut               ...
# Fair           0  ...      0      0      0      0      0      0      0      0
# Good           0  ...      0      1      0      0      0      0      0      0
# Ideal          0  ...      1      0      1      0      0      0      1      1
# Premium        1  ...      0      0      1      2      1      0      0      0
# Very Good      0  ...      0      0      0      0      0      1      0      0
#
# price      18818  18823
# ...

# %%
# 36. summary statistics of cut series of diamonds dataframe
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
# 37. create a histogram of carat series of diamonds dataframe
ax = df.plot.hist(column=['carat'],by='cut',figsize=(10,8))

# %%
# 38. to create a bar plot of the value_counts for the cut seriies of the dataframe
df.cut.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cut'>

# %%
# 39. pandas program to create a dataframe of booleans (True if missing, False if not missing) from diamonds dataframe
df.isnull().head(20)
# Out:
#     Unnamed: 0  carat    cut  color  clarity  depth  table  price      x  \
# 0        False  False  False  False    False  False  False  False  False
# 1        False  False  False  False    False  False  False  False  False
# 2        False  False  False  False    False  False  False  False  False
# 3        False  False  False  False    False  False  False  False  False
# 4        False  False  False  False    False  False  False  False  False
# 5        False  False  False  False    False  False  False  False  False
# 6        False  False  False  False    False  False  False  False  False
# 7        False  False  False  False    False  False  False  False  False
# 8        False  False  False  False    False  False  False  False  False
# 9        False  False  False  False    False  False  False  False  False
# 10       False  False  False  False    False  False  False  False  False
# 11       False  False  False  False    False  False  False  False  False
# ...

# %%
# 40. to count number of missing values in each series of dataframe
df.isnull().sum()
# Out:
# Unnamed: 0       0
# carat            0
# cut              0
# color            0
# clarity          0
# depth            0
# table            0
# price            0
# x                0
# y                0
# z                0
# Quality-color    0
# dtype: int64

# %%
# 41. check the number of rows and columns and drop those row if 'any' values are missing in row of diamonds dataframe
df.shape
# Out:
# (53940, 12)

# %%
df.dropna(how='any').shape
# Out:
# (53940, 12)

# %%
# 42. write pandas program to drop a row if any or all values in row are missing of diamonds dataframe on two specific columns
df.dropna(subset=['carat','cut'])
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z Quality-color
# ...

# %%
# 43. to set an existing column as the index of diamonds dataframe
df.set_index('color')
# Out:
#        Unnamed: 0  carat        cut clarity  depth  table  price     x     y  \
# color
# E               1   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98
# E               2   0.21    Premium     SI1   59.8   61.0    326  3.89  3.84
# E               3   0.23       Good     VS1   56.9   65.0    327  4.05  4.07
# I               4   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23
# J               5   0.31       Good     SI2   63.3   58.0    335  4.34  4.35
# ...           ...    ...        ...     ...    ...    ...    ...   ...   ...
# D           53936   0.72      Ideal     SI1   60.8   57.0   2757  5.75  5.76
# D           53937   0.72       Good     SI1   63.1   55.0   2757  5.69  5.75
# D           53938   0.70  Very Good     SI1   62.8   60.0   2757  5.66  5.68
# H           53939   0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12
# D           53940   0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87
#
#           z Quality-color
# color
# ...

# %%
# 44. to set an existing column as the index of diamonds dataframe and restore the index name, and move the index back to the column
df.set_index('color')
# Out:
#        Unnamed: 0  carat        cut clarity  depth  table  price     x     y  \
# color
# E               1   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98
# E               2   0.21    Premium     SI1   59.8   61.0    326  3.89  3.84
# E               3   0.23       Good     VS1   56.9   65.0    327  4.05  4.07
# I               4   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23
# J               5   0.31       Good     SI2   63.3   58.0    335  4.34  4.35
# ...           ...    ...        ...     ...    ...    ...    ...   ...   ...
# D           53936   0.72      Ideal     SI1   60.8   57.0   2757  5.75  5.76
# D           53937   0.72       Good     SI1   63.1   55.0   2757  5.69  5.75
# D           53938   0.70  Very Good     SI1   62.8   60.0   2757  5.66  5.68
# H           53939   0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12
# D           53940   0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87
#
#           z Quality-color
# color
# ...

# %%
df.reset_index()
# Out:
#        index  Unnamed: 0  carat        cut color clarity  depth  table  price  \
# 0          0           1   0.23      Ideal     E     SI2   61.5   55.0    326
# 1          1           2   0.21    Premium     E     SI1   59.8   61.0    326
# 2          2           3   0.23       Good     E     VS1   56.9   65.0    327
# 3          3           4   0.29    Premium     I     VS2   62.4   58.0    334
# 4          4           5   0.31       Good     J     SI2   63.3   58.0    335
# ...      ...         ...    ...        ...   ...     ...    ...    ...    ...
# 53935  53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757
# 53936  53936       53937   0.72       Good     D     SI1   63.1   55.0   2757
# 53937  53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757
# 53938  53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757
# 53939  53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757
#
# ...

# %%
# 45. to access a specified series index and the series values of the diamond dataframe
df['carat'][1]
# Out:
# 0.21

# %%
# 46. to sort a Series by its values and index of diamonds dataframe
df['price'].sort_values()
# Out:
# 0          326
# 1          326
# 2          327
# 3          334
# 4          335
#          ...
# 27745    18803
# 27746    18804
# 27747    18806
# 27748    18818
# 27749    18823
# Name: price, Length: 53940, dtype: int64

# %%
# 47. Write a Pandas program to calculate the multiply of length, width and depth for each cut of diamonds DataFrame.
df.x*df.y*df.z
# Out:
# 0         38.202030
# 1         34.505856
# 2         38.076885
# 3         46.724580
# 4         51.917250
#             ...
# 53935    115.920000
# 53936    118.110175
# 53937    114.449728
# 53938    140.766120
# 53939    124.568444
# Length: 53940, dtype: float64

# %%
# 48. Write a Pandas program to concatenate the diamonds DataFrame with the 'color' Series.
pd.concat([df,df.color],axis=1)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z Quality-color color
# ...

# %%
# 49. read specified rows and all columns
df.iloc[[1, 2, 3]]
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
#
#       z Quality-color
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I

# %%
# 50. program to read rows 0,5,7 and all columns of diamonds dataframe
df.iloc[[0, 5, 7]]
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 7           8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
#
#       y     z Quality-color
# 0  3.98  2.43      Ideal, E
# 5  3.96  2.48  Very Good, J
# 7  4.11  2.53  Very Good, H

# %%
# 51. read rows from 2 through 5
df.iloc[2:5]
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality-color
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %%
# 52. read rows 0 through 2(inclusive), columns 'color' and 'price'
df.iloc[0:3][['color', 'price']]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %%
# 53. read rows 0 through 2(inclusive), columns 'color' and 'price'
df.iloc[0:3][['color', 'price']]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %%
# 54. read rows in which 'cut' is 'premium', column 'color' of dataframe
df.loc[df['cut'] == 'Premium', 'price']
# Out:
# 1         326
# 3         334
# 12        342
# 14        345
# 15        345
#          ...
# 53928    2756
# 53930    2756
# 53931    2756
# 53934    2757
# 53938    2757
# Name: price, Length: 13791, dtype: int64

# %%
# 55. read rows in position 0 through 4, columns in position 0 through 3 of dataframe
df.iloc[0:5, [0,3]]
# Out:
#    Unnamed: 0 color
# 0           1     E
# 1           2     E
# 2           3     E
# 3           4     I
# 4           5     J

# %%
# 56. read rows in position 0 through 4, columns in position 1 through 4 of dataframe
df.iloc[0:4, [1,4]]
# Out:
#    carat clarity
# 0   0.23     SI2
# 1   0.21     SI1
# 2   0.23     VS1
# 3   0.29     VS2

# %%
# 57. read rows in position 0 through 4(exclusive), all columns
df.iloc[0:4]
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
#
#       z Quality-color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I

# %%
# 58. read rows in position 2 through 5 (inclusive), columns in position 0 through 2(exclusive) of dataframe
df.iloc[2:6, [0,2]]
# Out:
#    Unnamed: 0        cut
# 2           3       Good
# 3           4    Premium
# 4           5       Good
# 5           6  Very Good

# %%
# 59. concise summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     53940 non-null  int64
#  1   carat          53940 non-null  float64
#  2   cut            53940 non-null  object
#  3   color          53940 non-null  object
#  4   clarity        53940 non-null  object
#  5   depth          53940 non-null  float64
#  6   table          53940 non-null  float64
#  7   price          53940 non-null  int64
#  8   x              53940 non-null  float64
#  9   y              53940 non-null  float64
#  10  z              53940 non-null  float64
#  11  Quality-color  53940 non-null  object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 4.9+ MB

# %%
# 60. to get true memory usage by df dataframe
df.memory_usage(deep=True)
# Out:
# Index                132
# Unnamed: 0        431520
# carat             431520
# cut              2982154
# color            2697000
# clarity          2811070
# depth             431520
# table             431520
# price             431520
# x                 431520
# y                 431520
# z                 431520
# Quality-color    3143974
# dtype: int64

# %%
# 61. to get memory usage for each Series
df.memory_usage()
# Out:
# Index               132
# Unnamed: 0       431520
# carat            431520
# cut              431520
# color            431520
# clarity          431520
# depth            431520
# table            431520
# price            431520
# x                431520
# y                431520
# z                431520
# Quality-color    431520
# dtype: int64

# %%
# 62. to get random sample rows from diamonds
num = np.random.randint(len(df))
df.iloc[num]
# Out:
# Unnamed: 0            27440
# carat                  2.04
# cut                 Premium
# color                     F
# clarity                 SI2
# depth                  60.2
# table                  58.0
# price                 18066
# x                      8.17
# y                      8.24
# z                      4.94
# Quality-color    Premium, F
# Name: 27439, dtype: object

# %%
# 63. to get sample 75% of the diamonds DataFrame's rows without replacement and store the remaining 25% of the rows in another dataframe.
df.shape
# Out:
# (53940, 12)

# %%
# 75% of diamonds dataframe
res = df.sample(frac=0.75,random_state=99)
res
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 42653       42654   0.40    Premium     G      IF   60.8   58.0   1333  4.73
# 4069         4070   0.31  Very Good     D     SI1   63.0   55.0    571  4.32
# 27580       27581   1.60      Ideal     F     VS2   62.0   55.0  18421  7.49
# 33605       33606   0.31       Good     D     SI2   63.1   54.0    462  4.33
# 34415       34416   0.30      Ideal     G      IF   61.2   57.0    863  4.35
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 4677         4678   1.05    Premium     F     SI2   61.1   59.0   3672  6.54
# 34855       34856   0.30       Good     G    VVS2   63.8   56.0    878  4.29
# 13929       13930   2.00       Fair     I      I1   66.0   60.0   5667  7.78
# 31091       31092   0.33  Very Good     G    VVS2   62.8   57.0    752  4.39
# 41428       41429   0.53  Very Good     E     SI2   63.2   54.0   1227  5.19
#
#           y     z Quality-color
# ...

# %%
# 25% of the rows
df.loc[~df.index.isin(res.index),:]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 13             14   0.31      Ideal     J     SI2   62.2   54.0    344  4.35
# 14             15   0.20    Premium     E     SI2   60.2   62.0    345  3.79
# 18             19   0.30       Good     J     SI1   63.8   56.0    351  4.23
# 26             27   0.24    Premium     I     VS1   62.5   57.0    355  3.97
# 33             34   0.23  Very Good     E     VS1   59.5   58.0    402  4.01
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53919       53920   0.76      Ideal     I    VVS1   62.2   55.0   2753  5.89
# 53923       53924   0.73      Ideal     I     VS2   61.3   56.0   2756  5.80
# 53926       53927   0.71      Ideal     E     SI1   61.9   56.0   2756  5.71
# 53934       53935   0.72    Premium     D     SI1   62.7   59.0   2757  5.69
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
#
#           y     z Quality-color
# ...

# %%
# 64.Write a Pandas program to read the diamonds DataFrame and detect duplicate color.
df.clarity.duplicated().sum()
# Out:
# 53932

# %%
# 65. Write a Pandas program to count the duplicate rows of diamonds DataFrame.
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Length: 53940, dtype: bool
